# %% [markdown]
# # Workbook 01 - Solving beams with `sympy`

# %%
from sympy.physics.continuum_mechanics.beam import Beam
from sympy import symbols, nsimplify

# %% [markdown]
# # Task 01
#
# Create a `Beam` object to analyze a beam with the following attributes:
# * 14 ft long
# * E, I as symbols
# * Vertical supports @:
#     * 2 ft, 8 ft, 11 ft
# * Loads as follows:
#     * Point load: 500 lbs, @ 4 ft
#     * Trapezoidal load: 200 lbs @ 0 ft, 700 lbs @ 14 ft
#
# 1. Use `print()` to print the reactions
# 2. Plot the shear and moment diagrams
# 3. Plot the deflection assuming a W12x50

# %% [markdown]
# ## Task 01 Response

# %%
E, I = symbols("E I")
R1, R2, R3 = symbols("R1 R2 R3")

w12x50 = Beam(14, E, I)
w12x50.apply_load(500, 4, -1)
w12x50.apply_load(200, 0, 0)
w12x50.apply_load(500/14, 0, 1)

w12x50.apply_load(R1, 2, -1)
w12x50.apply_load(R2, 8, -1)
w12x50.apply_load(R3, 12, -1)

w12x50.bc_deflection = [(2, 0), (8, 0), (12, 0)]

w12x50.solve_for_reaction_loads(R1, R2, R3)

print(w12x50.reaction_loads)
w12x50.plot_shear_force()
w12x50.plot_bending_moment()
w12x50.plot_deflection(subs={E: 29e6, I: 164e6/25.4**4/12**4})
# Out:
# {R1: -1683.73015873016, R2: -2624.00793650794, R3: -2492.26190476191}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15568/3453656191.py in <module>
#      18 w12x50.plot_shear_force()
#      19 w12x50.plot_bending_moment()
# ---> 20 w12x50.plot_deflection(subs={E: 29e6, I: 164e6/25.4**4/12**4})
#
# ~\Anaconda3\lib\site-packages\sympy\physics\continuum_mechanics\beam.py in plot_deflection(self, subs)
#    1566             for x over (0.0, 8.0)
#    1567         """
# -> 1568         deflection = self.deflection()
#    1569         if subs is None:
#    1570             subs = {}
#
# ~\Anaconda3\lib\site-packages\sympy\physics\continuum_mechanics\beam.py in deflection(self)
#    1218                 bc_eqs.append(eqs)
#    1219             constants = list(linsolve(bc_eqs, (C3, C4)))
# -> 1220             deflection_curve = deflection_curve.subs({C3: constants[0][0], C4: constants[0][1]})
#    1221             return S.One/(E*I)*deflection_curve
#    1222
#
# IndexError: list index out of range

# %%
w12x50.load
# Out:
# 200*SingularityFunction(x, 0, 0) + 500*SingularityFunction(x, 0, 1) - 21100*SingularityFunction(x, 2, -1)/3 + 500*SingularityFunction(x, 4, -1) - 58750*SingularityFunction(x, 8, -1)/3 - 77050*SingularityFunction(x, 12, -1)/3

# %%
x = symbols("x")
shear_expr = w12x50.shear_force()
shear_expr
# Out:
# -200*SingularityFunction(x, 0, 1) - 250*SingularityFunction(x, 0, 2) + 21100*SingularityFunction(x, 2, 0)/3 - 500*SingularityFunction(x, 4, 0) + 58750*SingularityFunction(x, 8, 0)/3 + 77050*SingularityFunction(x, 12, 0)/3

# %%
shear_expr.subs({x: 2.332})
# Out:
# 5207.37733333333

# %%
w12x50.max_shear_force()
# Out:
# (Interval(8, 12), 36850/3)

# %% [markdown]
# # Task 02
#
# Create a `Beam` object to analyze a beam with the following attributes:
# * 3.6 m long
# * 45 MPa concrete, 300x600 dp beam
# * Fixed support @:
#     * 0 m
# * Loads as follows:
#     * UDL of self-weight
#     * UDL of 60 kN/m
#     * Point load of 175 kN @ 2.2 m
#
# 1. Use `print()` to print the reactions
# 2. Plot the shear and moment diagrams
# 3. Plot the deflection

# %% [markdown]
# ## Task 02 Response

# %%
# E, I = symbols("E I")
R1, R2 = symbols("R1 R2")
E = 4500*45**0.5
I = 300*600**3/12

cant_conc = Beam(3600, E, I)
cant_conc.apply_load(60, 0, 0)
cant_conc.apply_load(15.9, 0, 0)
cant_conc.apply_load(175000, 2200, -1)

cant_conc.apply_load(R1, 0, -1)
cant_conc.apply_load(R2, 0, -2)

cant_conc.bc_deflection = [(0, 0)]
cant_conc.bc_slope = [(0, 0)]

cant_conc.solve_for_reaction_loads(R1, R2)

print(cant_conc.reaction_loads)
cant_conc.plot_shear_force()
cant_conc.plot_bending_moment()
cant_conc.plot_deflection()
# Out:
# {R1: -448240.000000000, R2: 876832000.000000}
# C:\Users\cferster\Anaconda3\lib\site-packages\sympy\plotting\plot.py:1608: RuntimeWarning: invalid value encountered in double_scalars
#   cos_theta = dot_product / (vector_a_norm * vector_b_norm)

# %% [markdown]
# # Task 03
#
# Create a `Beam` object to analyze a core footing with the following attributes. You are going to assume a trapezoidal reaction load underneath the footing and solve for it.
#
# * 70 ft x 40 ft (analyze just the long direction)
# * 45 MPa concrete, 4 ft deep
# * Trapezoidal load as _vertical reaction_
# * Loads as follows:
#     * Footing self-weight
#     * 50 kip @ 12 ft
#     * 60 kip @ 30 ft
#     * -8000 kip-ft @ 30 ft
#     * -7500 kip-ft @ 40 ft
#     * 800 kip @ 40 ft
#     * 800 kip @ 60 ft
#
# 1. Use `print()` to print the reactions
# 2. Plot the shear and moment diagrams
#
# **Note** You won't be able to assign slope or deflection boundary conditions so you will only be able to solve for reactions, shear, and moment.

# %% [markdown]
# ## Task 03 Response

# %%
E, I = symbols("E I")
R1, R2 = symbols("R1 R2")
A = 50*4
w_W = A * 150 / 1000 # ft**2 * pcf / (lb/kip) -> kip/ft

core_ftg70 = Beam(70, E, I)
core_ftg70.apply_load(w_W, 0, 0)
core_ftg70.apply_load(50, 12, -1)
core_ftg70.apply_load(60, 30, -1)
core_ftg70.apply_load(-8000, 30, -2)
core_ftg70.apply_load(-7500, 40, -2)
core_ftg70.apply_load(800, 40, -1)
core_ftg70.apply_load(800, 60, -1)

core_ftg70.apply_load(R1, 0, 0)
core_ftg70.apply_load(R2, 0, 1)

core_ftg70.solve_for_reaction_loads(R1, R2)

print(core_ftg70.reaction_loads)
core_ftg70.plot_shear_force()
core_ftg70.plot_bending_moment()
# Out:
# {R1: -7.83673469387756, R2: -1.33119533527697}
